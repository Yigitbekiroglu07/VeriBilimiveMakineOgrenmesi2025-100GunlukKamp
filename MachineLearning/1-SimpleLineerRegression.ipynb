# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv('1-studyhours.csv')

# %%
df.head(5)
# Out:
#    Study Hours  Exam Score
# 0          3.9        40.0
# 1          9.6        57.1
# 2          4.5        42.7
# 3         11.4        65.1
# 4         14.4        78.7

# %%
df.info() # kaç data olduğunu verir
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Study Hours  33 non-null     float64
#  1   Exam Score   33 non-null     float64
# dtypes: float64(2)
# memory usage: 660.0 bytes

# %%
df.describe()
# Out:
#        Study Hours  Exam Score
# count    33.000000   33.000000
# mean     15.772727   74.612121
# std       7.608723   18.711206
# min       3.000000   40.000000
# 25%       9.600000   58.500000
# 50%      17.400000   78.800000
# 75%      21.300000   90.800000
# max      30.000000  100.000000

# %%
plt.scatter(df['Study Hours'],df['Exam Score'])
plt.xlabel('Study Hours')
plt.ylabel('Exam Score')
plt.show()

# %%
# Independent and dependent features

# %%
X = df[['Study Hours']]
y = df['Exam Score']

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
type(y)
# Out:
# pandas.core.series.Series

# %%
# test - train plit

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size= 0.2, random_state = 15)

# %%
y_train
# Out:
# 18     64.9
# 1      57.1
# 2      42.7
# 32     89.6
# 6      77.1
# 3      65.1
# 29     82.4
# 26     64.8
# 9      84.6
# 4      78.7
# 28     79.1
# 10     92.4
# 27     79.5
# 13    100.0
# 17     74.7
# 15     97.0
# 22     76.5
# 31     96.2
# 11     95.9
# 7      90.8
# 0      40.0
# 23     42.2
# 5      78.8
# 12     92.0
# 21     58.5
# 8      99.0
# Name: Exam Score, dtype: float64

# %%
y_test
# Out:
# 25    42.4
# 14    86.6
# 30    91.5
# 16    57.2
# 24    51.2
# 20    49.0
# 19    84.7
# Name: Exam Score, dtype: float64

# %%
# standardize the data set

# %%
from sklearn.preprocessing import StandardScaler

# %%
df.head()
# Out:
#    Study Hours  Exam Score
# 0          3.9        40.0
# 1          9.6        57.1
# 2          4.5        42.7
# 3         11.4        65.1
# 4         14.4        78.7

# %%
# Balanced feature values olması için çalışılır.
# Gradient descent’in daha  kararlı ve doğru çalışmasına olanak tanınır.
# L1 ve L2’de standart olması daha iyi çalışmasını sağlayacak. (Sonra göreceğiz.)

# %%
scaler=StandardScaler()

# %%
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %%
X_train
# Out:
# array([[ 0.11794385],
#        [-0.97424848],
#        [-1.68837424],
#        [ 0.32798083],
#        [ 0.36998823],
#        [-0.7222041 ],
#        [ 0.41199563],
#        [-0.97424848],
#        [ 0.11794385],
#        [-0.30213013],
#        [ 0.15995124],
#        [ 0.66404001],
#        [-0.13410054],
#        [ 1.50418796],
#        [-0.51216711],
#        [ 0.15995124],
#        [-0.30213013],
#        [ 1.21013618],
#        [ 1.33615837],
#        [ 0.7900622 ],
#        [-1.77238903],
#        [-1.89841122],
#        [ 0.20195864],
#        [ 1.88225453],
#        [-1.18428547],
#        [ 1.21013618]])

# %%
X_test
# Out:
# array([[-1.60435944],
#        [ 0.62203261],
#        [ 0.95809179],
#        [-1.52034465],
#        [-0.97424848],
#        [-1.77238903],
#        [ 0.66404001]])

# %%
from sklearn.linear_model import LinearRegression

# %%
regression = LinearRegression()

# %%
regression.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print("Coefficient: ", regression.coef_)
print("Intercept: " ,regression.intercept_)
# Out:
# Coefficient:  [16.17860223]
# Intercept:  76.9076923076923

# %%
# y = 76.91 + 16.18

# %%
plt.scatter(X_train, y_train)
plt.plot(X_train, regression.predict(X_train), "g")
plt.show()

# %%
# x = 20 --> y = ?

# %%
regression.predict([[20]])
# Out:
# array([400.47973694])

# %%
scaler.transform([[20]])
# Out:
# D:\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[0.48200796]])

# %%
regression.predict([[0.48200796]])
# Out:
# array([84.70590737])

# %%
regression.predict(scaler.transform([[10]]))
# Out:
# D:\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([62.05187491])

# %%
# prediction with test data

# %%
y_pred_test = regression.predict(X_test)

# %%
y_test
# Out:
# 25    42.4
# 14    86.6
# 30    91.5
# 16    57.2
# 24    51.2
# 20    49.0
# 19    84.7
# Name: Exam Score, dtype: float64

# %%
plt.scatter(y_pred_test,y_test)
plt.show()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
mse = mean_squared_error(y_test, y_pred_test)
mae = mean_absolute_error(y_test, y_pred_test)
rmse = np.sqrt(mse)
print("mse:" , mse)
print("mae:" , mae)
print("rmse:" , rmse)
# Out:
# mse: 29.45839048833392
# mae: 4.054868128856142
# rmse: 5.427558427906043

# %%
r2 = r2_score(y_test, y_pred_test)
print("r2 score ", r2)
# Out:
# r2 score  0.9196596206825491

# %%
# adjusted R Score formula
1 - (1-r2)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)
# Out:
# 0.903591544819059
