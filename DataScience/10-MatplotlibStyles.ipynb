# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data1 = np.linspace(0,10,20)

# %%
data1
# Out:
# array([ 0.        ,  0.52631579,  1.05263158,  1.57894737,  2.10526316,
#         2.63157895,  3.15789474,  3.68421053,  4.21052632,  4.73684211,
#         5.26315789,  5.78947368,  6.31578947,  6.84210526,  7.36842105,
#         7.89473684,  8.42105263,  8.94736842,  9.47368421, 10.        ])

# %%
data2 = data1 ** 2

# %%
plt.subplots()
# Out:
# (<Figure size 640x480 with 1 Axes>, <Axes: >)

# %%
my_fig, my_axes = plt.subplots()

# %%
type(my_fig)
# Out:
# matplotlib.figure.Figure

# %%
type(my_axes)
# Out:
# matplotlib.axes._axes.Axes

# %%
my_fig, my_axes = plt.subplots()
my_axes.plot(data1, data2, color = "#260701" , alpha = 0.5)
my_axes.plot(data2, data1, color = "#34c212")
plt.show()

# %%
(new_fig, new_axes) = plt.subplots()

new_axes.plot(data1, data1 + 2, color = "blue", linewidth = 1.0)
new_axes.plot(data1, data1 + 3, color = "yellow", linewidth = 4.0)

new_axes.plot(data1, data1 + 4, color = "#ff4a16", linestyle = "-.")
new_axes.plot(data1, data1 + 5, color = "#ff4a16", linestyle = ":")
new_axes.plot(data1, data1 + 6, color = "#ff4a16", linestyle = "--")

new_axes.plot(data1, data1 + 7, color = "#000000", linestyle = ":", marker = "o", markersize = 8, markerfacecolor = "red")
new_axes.plot(data1, data1 + 8, color = "#000000", linestyle = ":", marker = "+", markersize = 10)

plt.show()

# %%
# scatter

# %%
plt.scatter(data1,data2)
plt.show()

# %%
# histogram

# %%
new_array = np.random.randint(0,50,20)

# %%
new_array
# Out:
# array([35, 47, 49, 22,  8, 33,  1, 14, 40, 44, 49, 34, 34, 12, 21,  0, 40,
#        29,  7,  1])

# %%
plt.hist(new_array)
plt.show()

# %%
# boxplot

# %%
plt.boxplot(new_array)
plt.show()
